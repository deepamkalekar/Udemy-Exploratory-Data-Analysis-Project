# %%
# Load EDA Packages
import pandas as pd
import numpy as np

# %%
# Load Data Viz pkgs
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Hide All Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Load Dataset
df = pd.read_csv("udemy_courses.csv")

# %%
df.head(5)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %% [raw]
# EDA on Subject/Category
#   +Subjects/Category
#     -What is the distribution of subjects
#     -How many courses per subject
#     -How many people purchase a particular subject
#     -Which subject is the most popular

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
# What is the distribution of subjects
df['subject'].unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %%
len(df['subject'].unique())
# Out:
# 4

# %%
# How many courses per subject
df['subject'].value_counts()
# Out:
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
plt.figure(figsize=(10,5))
df['subject'].value_counts().plot(kind='pie')
plt.show()

# %%
# Method 2 using seaborn
sns.countplot(df['subject'])
plt.title('Plot Of Value Count Per Subject')
plt.xticks(rotation=45)
plt.show()

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df['is_paid'].unique()
# Out:
# array([ True, False])

# %%
df['is_paid'].value_counts()
# Out:
# True     3368
# False     310
# Name: is_paid, dtype: int64

# %%
df.head(5)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
# Number of subscribers per subject 
df.groupby('subject')['num_subscribers'].sum()
# Out:
# subject
# Business Finance       1868711
# Graphic Design         1063148
# Musical Instruments     846689
# Web Development        7980572
# Name: num_subscribers, dtype: int64

# %%
df.groupby('subject')['num_subscribers'].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='subject'>

# %%
df.groupby('subject')['num_subscribers'].sum().plot(kind='pie', autopct='%0.1f%%')
plt.savefig('num_sub_per_sub.png',bbox_inches='tight', pad_inches=2, transparent=True)

# %%
#Total number of subscriber
df['num_subscribers'].sum()
# Out:
# 11759120

# %%
# Average number of subscribers
df['num_subscribers'].mean()
# Out:
# 3197.150625339859

# %%
df['num_subscribers'].describe()
# Out:
# count      3678.000000
# mean       3197.150625
# std        9504.117010
# min           0.000000
# 25%         111.000000
# 50%         911.500000
# 75%        2546.000000
# max      268923.000000
# Name: num_subscribers, dtype: float64

# %%
#Which course has the heighest number of subscribers
df['num_subscribers'].idxmax()
# Out:
# 2827

# %%
df.iloc[2827]
# Out:
# course_id                                                          41295
# course_title                        Learn HTML5 Programming From Scratch
# url                    https://www.udemy.com/learn-html5-programming-...
# is_paid                                                            False
# price                                                                  0
# num_subscribers                                                   268923
# num_reviews                                                         8629
# num_lectures                                                          45
# level                                                         All Levels
# content_duration                                                    10.5
# published_timestamp                                 2013-02-14T07:03:41Z
# subject                                                  Web Development
# Name: 2827, dtype: object

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
# How many Level udemy have
len(df['level'].unique())
# Out:
# 4

# %%
# What is the distribution of courses per level
df['level'].value_counts()
# Out:
# All Levels            1929
# Beginner Level        1270
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
df['level'].value_counts().plot(kind='bar')
plt.savefig('dist_course_pr_level.png',bbox_inches='tight', pad_inches=2, transparent=True)

# %%
# How many subscribers per level
df.groupby('level')['num_subscribers'].sum()
# Out:
# level
# All Levels            6915076
# Beginner Level        4051843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %%
df.groupby('level')['num_subscribers'].sum().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='num_subscribers'>

# %%
# How many course per level
df.groupby('level')['course_id'].count()
# Out:
# level
# All Levels            1929
# Beginner Level        1270
# Expert Level            58
# Intermediate Level     421
# Name: course_id, dtype: int64

# %%
# How many levels per subject category
df.groupby('subject')['level'].value_counts()
# Out:
# subject              level
# Business Finance     All Levels            696
#                      Beginner Level        340
#                      Intermediate Level    128
#                      Expert Level           31
# Graphic Design       All Levels            298
#                      Beginner Level        243
#                      Intermediate Level     57
#                      Expert Level            5
# Musical Instruments  Beginner Level        296
#                      All Levels            276
#                      Intermediate Level    101
#                      Expert Level            7
# Web Development      All Levels            659
#                      Beginner Level        391
#                      Intermediate Level    135
#                      Expert Level           15
# Name: level, dtype: int64

# %%
df.groupby('subject')['level'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='subject,level'>

# %%
#using seaborn
plt.figure(figsize=(10,7))
sns.barplot(x='level', y='num_subscribers', hue='subject', data=df, ci=None)
# Out:
# <AxesSubplot:xlabel='level', ylabel='num_subscribers'>

# %%
def plot_feature(feature):
    #using  seaborn 
    plt.figure(figsize=(10,7))
    plt.title("Plot of {} per level per subject".format(feature))
    sns.barplot(x='level',y=feature, hue='subject', data=df, ci=None)
    plt.show()
    
    plt.figure(figsize=(10,7))
    plt.title("Plot of {} per level".format(feature))
    df.groupby('level')[feature].sum().plot(kind='pie')
    plt.show()

# %%
plot_feature('num_reviews')

# %%
plot_feature('num_lectures')

# %%
df.head(5)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
# What is the average price of course 
df['price'].mean()
# Out:
# 66.0494834148994

# %%
df.price.unique()
# Out:
# array([200,  75,  45,  95, 150,  65, 195,  30,  20,  50, 175, 140, 115,
#        190, 125,  60, 145, 105, 155, 185, 180, 120,  25, 160,  40,   0,
#        100,  90,  35,  80,  70,  55, 165, 130,  85, 170, 110, 135],
#       dtype=int64)

# %%
# What is the describe price of course
df['price'].describe()
# Out:
# count    3678.000000
# mean       66.049483
# std        61.005755
# min         0.000000
# 25%        20.000000
# 50%        45.000000
# 75%        95.000000
# max       200.000000
# Name: price, dtype: float64

# %%
#which is the highest price course
df['price'].idxmax()
# Out:
# 0

# %%
df.iloc[0]
# Out:
# course_id                                                        1070968
# course_title                          Ultimate Investment Banking Course
# url                    https://www.udemy.com/ultimate-investment-bank...
# is_paid                                                             True
# price                                                                200
# num_subscribers                                                     2147
# num_reviews                                                           23
# num_lectures                                                          51
# level                                                         All Levels
# content_duration                                                     1.5
# published_timestamp                                 2017-01-18T20:58:58Z
# subject                                                 Business Finance
# Name: 0, dtype: object

# %%
# which is the most profitable course
#price * num_subscribers
df['profit']=df['price']*df['num_subscribers']

# %%
df['profit'].idxmax()
# Out:
# 3230

# %%
df.iloc[3230]
# Out:
# course_id                                                         625204
# course_title                                  The Web Developer Bootcamp
# url                    https://www.udemy.com/the-web-developer-bootcamp/
# is_paid                                                             True
# price                                                                200
# num_subscribers                                                   121584
# num_reviews                                                        27445
# num_lectures                                                         342
# level                                                         All Levels
# content_duration                                                    43.0
# published_timestamp                                 2015-11-02T21:13:27Z
# subject                                                  Web Development
# profit                                                          24316800
# ...

# %%
# how many courses on udemy are free and paid 
df['is_paid'].unique()
# Out:
# array([ True, False])

# %%
df['is_paid'].value_counts()
# Out:
# True     3368
# False     310
# Name: is_paid, dtype: int64

# %%
df['is_paid'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
sns.countplot(df['is_paid'])
# Out:
# <AxesSubplot:xlabel='is_paid', ylabel='count'>

# %%
# how many paid or free courses in each subject catogory 
df.head(5)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.groupby('subject')['is_paid'].value_counts()
# Out:
# subject              is_paid
# Business Finance     True       1099
#                      False        96
# Graphic Design       True        568
#                      False        35
# Musical Instruments  True        634
#                      False        46
# Web Development      True       1067
#                      False       133
# Name: is_paid, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='level', y='is_paid', hue='subject', data=df, ci=None)
plt.show()

# %%
# Does price depend on the number of subscribers
sns.scatterplot(data=df, x='price', y='num_subscribers')
# Out:
# <AxesSubplot:xlabel='price', ylabel='num_subscribers'>

# %%
# Does price depend on the number of reviews
sns.scatterplot(data=df, x='price', y='num_reviews')
# Out:
# <AxesSubplot:xlabel='price', ylabel='num_reviews'>

# %%
plt.figure(figsize=(15,10))
plt.title('Does price influence subscribtion per subject category')
sns.lineplot(data=df, x='price', y='num_subscribers', hue='subject')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.title('Does Reviews influence subscribtion per subject category')
sns.lineplot(data=df, x='num_reviews', y='num_subscribers', hue='subject')
plt.show()

# %%
df.head(5)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df['published_timestamp'].dtype
# Out:
# dtype('O')

# %%
df['published_timestamp'].head(5)
# Out:
# 0    2017-01-18T20:58:58Z
# 1    2017-03-09T16:34:20Z
# 2    2016-12-19T19:26:30Z
# 3    2017-05-30T20:07:24Z
# 4    2016-12-13T14:57:18Z
# Name: published_timestamp, dtype: object

# %%
df['published_timestamp'].str.split('T')
# Out:
# 0       [2017-01-18, 20:58:58Z]
# 1       [2017-03-09, 16:34:20Z]
# 2       [2016-12-19, 19:26:30Z]
# 3       [2017-05-30, 20:07:24Z]
# 4       [2016-12-13, 14:57:18Z]
#                  ...
# 3673    [2016-06-14, 17:36:46Z]
# 3674    [2017-03-10, 22:24:30Z]
# 3675    [2015-12-30, 16:41:42Z]
# 3676    [2016-08-11, 19:06:15Z]
# 3677    [2014-09-28, 19:51:11Z]
# Name: published_timestamp, Length: 3678, dtype: object

# %%
df['published_timestamp'].str.split('T').str.get(0)
# Out:
# 0       2017-01-18
# 1       2017-03-09
# 2       2016-12-19
# 3       2017-05-30
# 4       2016-12-13
#            ...
# 3673    2016-06-14
# 3674    2017-03-10
# 3675    2015-12-30
# 3676    2016-08-11
# 3677    2014-09-28
# Name: published_timestamp, Length: 3678, dtype: object

# %%
df['published_date']=df['published_timestamp'].str.split('T').str.get(0)

# %%
df['published_date']
# Out:
# 0       2017-01-18
# 1       2017-03-09
# 2       2016-12-19
# 3       2017-05-30
# 4       2016-12-13
#            ...
# 3673    2016-06-14
# 3674    2017-03-10
# 3675    2015-12-30
# 3676    2016-08-11
# 3677    2014-09-28
# Name: published_date, Length: 3678, dtype: object

# %%
df['published_date'].str.split('-')
# Out:
# 0       [2017, 01, 18]
# 1       [2017, 03, 09]
# 2       [2016, 12, 19]
# 3       [2017, 05, 30]
# 4       [2016, 12, 13]
#              ...
# 3673    [2016, 06, 14]
# 3674    [2017, 03, 10]
# 3675    [2015, 12, 30]
# 3676    [2016, 08, 11]
# 3677    [2014, 09, 28]
# Name: published_date, Length: 3678, dtype: object

# %%
df['year'] = df['published_date'].str.split('-').str.get(0)
df['month'] = df['published_date'].str.split('-').str.get(1)
df['day'] = df['published_date'].str.split('-').str.get(2)

# %%
df['year']
# Out:
# 0       2017
# 1       2017
# 2       2016
# 3       2017
# 4       2016
#         ...
# 3673    2016
# 3674    2017
# 3675    2015
# 3676    2016
# 3677    2014
# Name: year, Length: 3678, dtype: object

# %%
    # number of subscribers per year
df.groupby('year')['num_subscribers'].sum()
# Out:
# year
# 2011     119028
# 2012     555339
# 2013    1723438
# 2014    1930406
# 2015    3475324
# 2016    2966644
# 2017     988941
# Name: num_subscribers, dtype: int64

# %%
df.groupby('year')['num_subscribers'].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
plt.figure(figsize=(15,10))
plt.title("Plot of subscription per year per category")
sns.lineplot(data=df, x='year', y='num_subscribers', hue='subject')
plt.show()
